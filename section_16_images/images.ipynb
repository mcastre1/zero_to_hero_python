# %%
from PIL import Image

# %%
mac = Image.open("./example.jpg")

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac.size
# Out:
# (1993, 1257)

# %%
mac.filename
# Out:
# './example.jpg'

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
# Cropping Images

# %%
mac.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x177C7FAA9A0>

# %%
pencils = Image.open("./pencils.jpg")

# %%
pencils.size
# Out:
# (1950, 1300)

# %%
x = 0
y = 0

w = 1950/3
h = 1300/10

# %%
pencils.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=650x130 at 0x177C8557D30>

# %%
x = 0
y = 1100

w = 1950/3
h = 1300

# %%
pencils.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=650x200 at 0x177C57DF220>

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257 at 0x177C57F5250>

# %%
mac.size
# Out:
# (1993, 1257)

# %%
halfway = 1993/2

# %%
x = halfway - 200

# %%
w = halfway + 200

# %%
y = 800

# %%
h = 1257

# %%
mac.crop((x,y,w,h))
# Out:
# <PIL.Image.Image image mode=RGB size=400x457 at 0x177C57DF520>

# %%
computer = mac.crop((x,y,w,h))

# %%
mac.paste(im=computer, box=(796,0))

# %%
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257 at 0x177C57F5250>

# %%
mac.size
# Out:
# (1993, 1257)

# %%
mac.resize((3000,500))
# Out:
# <PIL.Image.Image image mode=RGB size=3000x500 at 0x177C572AD90>

# %%
mac.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=1993x1257 at 0x177C8555A60>

# %%
red = Image.open("./red_color.jpg")

# %%
blue = Image.open("./blue_color.png")

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=200x200 at 0x177C57EFEE0>

# %%
red.putalpha(100)

# %%
red
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=200x200 at 0x177C7FAA8E0>

# %%
red.paste(im=blue, box=(0,0),mask=blue)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-e2e118ae4d7a> in <module>
# ----> 1 red.paste(im=blue, box=(0,0),mask=blue)
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in paste(self, im, box, mask)
#    1523         if mask:
#    1524             mask.load()
# -> 1525             self.im.paste(im, box, mask.im)
#    1526         else:
#    1527             self.im.paste(im, box)
#
# ValueError: bad transparency mask

# %%
blue
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=200x200 at 0x177C7D4BE20>

# %%
blue.save("bluenew.png")
